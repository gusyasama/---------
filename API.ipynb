# %%
import requests

url = 'https://webservice.recruit.co.jp/hotpepper/gourmet/v1/'

start = 1
count = 100

params = {
    'key':'349e0c72b02d8dee',
    'keyword':'五反田駅',
    'format':'json',
    'start':start,
    'count':count
}
res = requests.get(url, params)

shops = res.json()['results']['shop']
shops[:3]
# Out:
# [{'id': 'J004402152',
#   'name': '海坊主五反田駅前店',
#   'logo_image': 'https://imgfp.hotp.jp/SYS/cmn/images/common/diary/custom/m30_img_noimage.gif',
#   'name_kana': 'うみぼうずごたんだえきまえてん',
#   'address': '東京都品川区西五反田２-７-８ 誠實ビル7階',
#   'station_name': '五反田',
#   'ktai_coupon': 0,
#   'large_service_area': {'code': 'SS10', 'name': '関東'},
#   'service_area': {'code': 'SA11', 'name': '東京'},
#   'large_area': {'code': 'Z011', 'name': '東京'},
#   'middle_area': {'code': 'Y025', 'name': '品川･目黒･田町･浜松町･五反田'},
#   'small_area': {'code': 'X086', 'name': '五反田'},
#   'lat': 35.6263279137,
#   'lng': 139.7224702104,
#   'genre': {'name': '居酒屋', 'catch': '鮮魚とお肉料理を地酒と供に堪能できる', 'code': 'G001'},
#   'sub_genre': {'name': '中華', 'code': 'G007'},
#   'budget': {'code': 'B003',
#    'name': '3001～4000円',
#    'average': 'ランチ：900円\u3000ディナー：3000円'},
#   'catch': '気軽に楽しめるランチ 多彩なコースで満足◎',
#   'capacity': 95,
#   'access': 'ＪＲ五反田駅西口より徒歩約2分',
#   'mobile_access': 'JR五反田駅西口より徒歩約2分',
#   'urls': {'pc': 'https://www.hotpepper.jp/strJ004402152/?vos=nhppalsa000016'},
#   'photo': {'pc': {'l': 'https://imgfp.hotp.jp/IMGH/64/95/P047976495/P047976495_238.jpg',
#     'm': 'https://imgfp.hotp.jp/IMGH/64/95/P047976495/P047976495_168.jpg',
#     's': 'https://imgfp.hotp.jp/IMGH/64/95/P047976495/P047976495_58_s.jpg'},
#    'mobile': {'l': 'https://imgfp.hotp.jp/IMGH/64/95/P047976495/P047976495_168.jpg',
#     's': 'https://imgfp.hotp.jp/IMGH/64/95/P047976495/P047976495_100.jpg'}},
#   'open': '月～日、祝日、祝前日: 11:00～14:30 （料理L.O. 14:00 ドリンクL.O. 14:00）16:30～翌0:00 （料理L.O. 23:00 ドリンクL.O. 23:00）',
#   'close': 'なし',
#   'party_capacity': 95,
#   'other_memo': '複数言語対応スタッフ在籍（中国語）、写真付きメニューあり、デジタルメニューあり',
#   'shop_detail_memo': '',
#   'budget_memo': 'お通し385円（税込）',
#   'wedding': '要相談',
#   'course': 'あり',
#   'free_drink': 'あり',
#   'free_food': 'なし',
#   'private_room': 'あり ：6人可、8人可、10～20人可、20～30人可、30人以上可（55名まで可能）',
#   'horigotatsu': 'なし',
#   'tatami': 'なし',
#   'card': '利用可',
#   'non_smoking': '禁煙席なし',
#   'charter': '貸切可 ：20人～50人可、50人以上可',
#   'parking': 'なし ：近隣にコインパーキングあり',
#   'barrier_free': 'なし',
#   'show': 'なし',
#   'karaoke': 'なし',
#   'band': '不可',
#   'tv': 'なし',
#   'lunch': 'あり',
#   'midnight': '営業していない',
#   'english': 'あり',
#   'pet': '不可',
#   'child': 'お子様連れOK',
#   'wifi': 'あり',
#   'coupon_urls': {'pc': 'https://www.hotpepper.jp/strJ004402152/map/?vos=nhppalsa000016',
#    'sp': 'https://www.hotpepper.jp/strJ004402152/scoupon/?vos=nhppalsa000016'}},
#  {'id': 'J000132490',
#   'name': '王豚足家 オウトンソクヤ 五反田本店',
#   'logo_image': 'https://imgfp.hotp.jp/IMGH/25/05/P047432505/P047432505_69.jpg',
#   'name_kana': 'かんこくりょうり\u3000おうとんそくや\u3000ごたんだほんてん',
#   'address': '東京都品川区西五反田１－４－２',
#   'station_name': '五反田',
#   'ktai_coupon': 0,
#   'large_service_area': {'code': 'SS10', 'name': '関東'},
#   'service_area': {'code': 'SA11', 'name': '東京'},
#   'large_area': {'code': 'Z011', 'name': '東京'},
#   'middle_area': {'code': 'Y025', 'name': '品川･目黒･田町･浜松町･五反田'},
#   'small_area': {'code': 'X086', 'name': '五反田'},
#   'lat': 35.6253499917,
#   'lng': 139.7233551747,
#   'genre': {'name': '居酒屋', 'catch': '五反田駅徒歩1分で本場韓国料理が味わえる', 'code': 'G001'},
#   'sub_genre': {'name': '韓国料理', 'code': 'G017'},
#   'budget': {'code': 'B008',
#    'name': '4001～5000円',
#    'average': 'ランチ￥1,000～￥1,999\u3000ディナー￥4,000～￥4,999'},
#   'catch': '好立地で五反田駅から1分 種類豊富なマッコリで乾杯',
#   'capacity': 54,
#   'access': 'ＪＲ五反田駅西口から 徒歩1分 (旧野村証券ビル裏)/五反田駅から87m',
#   'mobile_access': 'JR五反田駅西口から 徒歩1分 (旧野村証券ﾋﾞﾙ裏)',
#   'urls': {'pc': 'https://www.hotpepper.jp/strJ000132490/?vos=nhppalsa000016'},
#   'photo': {'pc': {'l': 'https://imgfp.hotp.jp/IMGH/19/08/P047561908/P047561908_238.jpg',
#     'm': 'https://imgfp.hotp.jp/IMGH/19/08/P047561908/P047561908_168.jpg',
#     's': 'https://imgfp.hotp.jp/IMGH/19/08/P047561908/P047561908_58_s.jpg'},
#    'mobile': {'l': 'https://imgfp.hotp.jp/IMGH/19/08/P047561908/P047561908_168.jpg',
#     's': 'https://imgfp.hotp.jp/IMGH/19/08/P047561908/P047561908_100.jpg'}},
#   'open': '月: 11:30～14:30 （料理L.O. 14:00 ドリンクL.O. 14:00）17:00～23:00 （料理L.O. 22:30 ドリンクL.O. 22:30）火～木: 11:30～14:30 （料理L.O. 14:00 ドリンクL.O. 14:00）17:00～翌0:00 （料理L.O. 23:30 ドリンクL.O. 23:30）金: 11:30～14:30 （料理L.O. 14:00 ドリンクL.O. 14:00）17:00～翌4:00 （料理L.O. 翌3:30 ドリンクL.O. 翌3:30）土: 17:00～翌4:00 （料理L.O. 翌3:30 ドリンクL.O. 翌3:30）',
#   'close': '日',
#   'party_capacity': 40,
#   'other_memo': '',
#   'shop_detail_memo': '',
#   'budget_memo': 'お通し代330円\u3000基本1ドリンク制',
#   'wedding': '',
#   'course': 'あり',
#   'free_drink': 'あり',
#   'free_food': 'あり',
#   'private_room': 'なし',
#   'horigotatsu': 'なし',
#   'tatami': 'あり',
#   'card': '利用可',
#   'non_smoking': '禁煙席なし',
#   'charter': '貸切可 ：10名様以上より貸切でご利用可能です\u3000※要予約',
#   'parking': 'なし ：なし',
#   'barrier_free': 'なし',
#   'show': 'なし',
#   'karaoke': 'なし',
#   'band': '不可',
#   'tv': 'なし',
#   'lunch': 'あり',
#   'midnight': '営業している',
#   'english': 'なし',
#   'pet': '不可',
#   'child': 'お子様連れOK',
#   'wifi': 'あり',
#   'coupon_urls': {'pc': 'https://www.hotpepper.jp/strJ000132490/map/?vos=nhppalsa000016',
#    'sp': 'https://www.hotpepper.jp/strJ000132490/scoupon/?vos=nhppalsa000016'}},
#  {'id': 'J001278727',
#   'name': '幻の和牛と三崎港直送鮮魚 MORGEN 五反田駅前店',
#   'logo_image': 'https://imgfp.hotp.jp/IMGH/61/19/P043556119/P043556119_69.jpg',
#   'name_kana': 'まぼろしのわぎゅうとみさきこうちょくそうせんぎょ\u3000もるげん\u3000ごたんだえきまえてん',
#   'address': '東京都品川区西五反田１-18-1 五反田EXビル7F',
#   'station_name': '五反田',
#   'ktai_coupon': 0,
#   'large_service_area': {'code': 'SS10', 'name': '関東'},
#   'service_area': {'code': 'SA11', 'name': '東京'},
#   'large_area': {'code': 'Z011', 'name': '東京'},
#   'middle_area': {'code': 'Y025', 'name': '品川･目黒･田町･浜松町･五反田'},
#   'small_area': {'code': 'X086', 'name': '五反田'},
#   'lat': 35.6236373946,
#   'lng': 139.7229169473,
#   'genre': {'name': '居酒屋', 'catch': '＃鮮魚＃和牛＃日本酒＃クラフトビール', 'code': 'G001'},
#   'sub_genre': {'name': '和食', 'code': 'G004'},
#   'budget': {'code': 'B003', 'name': '3001～4000円', 'average': '￥3,300'},
#   'catch': '高鮮度食材の創作料理 足を使って納得した食材を',
#   'capacity': 70,
#   'access': '五反田駅徒歩3分／大崎広小路駅徒歩1分／大崎駅徒歩10分',
#   'mobile_access': '五反田駅徒歩3分/大崎広小路駅徒歩1分/大崎駅徒歩10分',
#   'urls': {'pc': 'https://www.hotpepper.jp/strJ001278727/?vos=nhppalsa000016'},
#   'photo': {'pc': {'l': 'https://imgfp.hotp.jp/IMGH/40/57/P048924057/P048924057_238.jpg',
#     'm': 'https://imgfp.hotp.jp/IMGH/40/57/P048924057/P048924057_168.jpg',
#     's': 'https://imgfp.hotp.jp/IMGH/40/57/P048924057/P048924057_58_s.jpg'},
#    'mobile': {'l': 'https://imgfp.hotp.jp/IMGH/40/57/P048924057/P048924057_168.jpg',
#     's': 'https://imgfp.hotp.jp/IMGH/40/57/P048924057/P048924057_100.jpg'}},
#   'open': '月、日、祝日: 17:00～22:30 （料理L.O. 22:00 ドリンクL.O. 22:15）火～土、祝前日: 17:00～23:00 （料理L.O. 22:30 ドリンクL.O. 22:45）',
#   'close': 'なし',
#   'party_capacity': 50,
#   'other_memo': '',
#   'shop_detail_memo': '電話でのお問い合わせは14時から可能です。',
#   'budget_memo': '',
#   'wedding': 'プロジェクター完備！貸切宴会にも最適なスペースです◎',
#   'course': 'あり',
#   'free_drink': 'あり',
#   'free_food': 'なし',
#   'private_room': 'あり ：【要予約】完全個室です。4～6名様用・1室のみ',
#   'horigotatsu': 'なし',
#   'tatami': 'なし',
#   'card': '利用可',
#   'non_smoking': '全面禁煙',
#   'charter': '貸切可 ：40名様から貸切OKです♪\u3000お気軽にご連絡くださいませ。',
#   'parking': 'あり ：お近くに駐車場がございます。',
#   'barrier_free': 'なし',
#   'show': 'なし',
#   'karaoke': 'なし',
#   'band': '不可',
#   'tv': 'あり',
#   'lunch': 'なし',
#   'midnight': '営業していない',
#   'english': 'あり',
#   'pet': '不可',
#   'child': 'お子様連れOK ：11歳までは半額◎',
#   'wifi': '未確認',
#   'coupon_urls': {'pc': 'https://www.hotpepper.jp/strJ001278727/map/?vos=nhppalsa000016',
#    'sp': 'https://www.hotpepper.jp/strJ001278727/scoupon/?vos=nhppalsa000016'}}]

# %%
len(shops)
# Out:
# 37

# %%
shop = shops[0]

# %%
datum = {
    'name':shop['name'],
    'address': shop['address'],
    'capacity': shop['capacity'],
    'access': shop['access'],
    'open' :shop['open'],
    'budget': shop['budget']['name'],
    'urls' : shop['urls']['pc']
}

datum
# Out:
# {'name': '海坊主五反田駅前店',
#  'address': '東京都品川区西五反田２-７-８ 誠實ビル7階',
#  'capacity': 95,
#  'access': 'ＪＲ五反田駅西口より徒歩約2分',
#  'open': '月～日、祝日、祝前日: 11:00～14:30 （料理L.O. 14:00 ドリンクL.O. 14:00）16:30～翌0:00 （料理L.O. 23:00 ドリンクL.O. 23:00）',
#  'budget': '3001～4000円',
#  'urls': 'https://www.hotpepper.jp/strJ004402152/?vos=nhppalsa000016'}

# %%
data = []
for shop in shops:
    datum = {
        'name': shop['name'],
        'address': shop['address'],
        'capacity': shop['capacity'],
        'access': shop['access'],
        'open': shop['open'],
        'budget': shop['budget']['name'],
        'urls': shop['urls']['pc']
    }
    data.append(datum)

# %%
data[:5]
# Out:
# [{'name': '海坊主五反田駅前店',
#   'address': '東京都品川区西五反田２-７-８ 誠實ビル7階',
#   'capacity': 95,
#   'access': 'ＪＲ五反田駅西口より徒歩約2分',
#   'open': '月～日、祝日、祝前日: 11:00～14:30 （料理L.O. 14:00 ドリンクL.O. 14:00）16:30～翌0:00 （料理L.O. 23:00 ドリンクL.O. 23:00）',
#   'budget': '3001～4000円',
#   'urls': 'https://www.hotpepper.jp/strJ004402152/?vos=nhppalsa000016'},
#  {'name': '王豚足家 オウトンソクヤ 五反田本店',
#   'address': '東京都品川区西五反田１－４－２',
#   'capacity': 54,
#   'access': 'ＪＲ五反田駅西口から 徒歩1分 (旧野村証券ビル裏)/五反田駅から87m',
#   'open': '月: 11:30～14:30 （料理L.O. 14:00 ドリンクL.O. 14:00）17:00～23:00 （料理L.O. 22:30 ドリンクL.O. 22:30）火～木: 11:30～14:30 （料理L.O. 14:00 ドリンクL.O. 14:00）17:00～翌0:00 （料理L.O. 23:30 ドリンクL.O. 23:30）金: 11:30～14:30 （料理L.O. 14:00 ドリンクL.O. 14:00）17:00～翌4:00 （料理L.O. 翌3:30 ドリンクL.O. 翌3:30）土: 17:00～翌4:00 （料理L.O. 翌3:30 ドリンクL.O. 翌3:30）',
#   'budget': '4001～5000円',
#   'urls': 'https://www.hotpepper.jp/strJ000132490/?vos=nhppalsa000016'},
#  {'name': '幻の和牛と三崎港直送鮮魚 MORGEN 五反田駅前店',
#   'address': '東京都品川区西五反田１-18-1 五反田EXビル7F',
#   'capacity': 70,
#   'access': '五反田駅徒歩3分／大崎広小路駅徒歩1分／大崎駅徒歩10分',
#   'open': '月、日、祝日: 17:00～22:30 （料理L.O. 22:00 ドリンクL.O. 22:15）火～土、祝前日: 17:00～23:00 （料理L.O. 22:30 ドリンクL.O. 22:45）',
#   'budget': '3001～4000円',
#   'urls': 'https://www.hotpepper.jp/strJ001278727/?vos=nhppalsa000016'},
#  {'name': '酒蔵 桜ちょうちん 五反田',
#   'address': '東京都品川区西五反田１‐4‐2 秀和五反田駅前レジデンス2階',
#   'capacity': 150,
#   'access': 'JR五反田駅徒歩２分/都営浅草線五反田駅徒歩２分/東急池上線五反田駅徒歩２分',
#   'open': '月～金: 16:00～23:30 （料理L.O. 22:30 ドリンクL.O. 23:00）土: 14:00～23:30 （料理L.O. 22:30 ドリンクL.O. 23:00）',
#   'budget': '3001～4000円',
#   'urls': 'https://www.hotpepper.jp/strJ003893833/?vos=nhppalsa000016'},
#  {'name': '居酒屋 せんや 五反田駅本店',
#   'address': '東京都品川区東五反田１-17-7大宗五反田ビル202',
#   'capacity': 100,
#   'access': '各線五反田駅東口徒歩２分／鹿児島黒牛や鮮度抜群の刺身を完全個室で堪能♪',
#   'open': '月～金、日、祝前日: 16:00～翌0:00 （料理L.O. 23:00 ドリンクL.O. 23:30）土、祝日: 16:00～23:00 （料理L.O. 22:00 ドリンクL.O. 22:30）',
#   'budget': '3001～4000円',
#   'urls': 'https://www.hotpepper.jp/strJ001244947/?vos=nhppalsa000016'}]

# %%
import pandas as pd
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#                          name                         address  capacity  \
# 0                   海坊主五反田駅前店          東京都品川区西五反田２-７-８ 誠實ビル7階        95
# 1          王豚足家 オウトンソクヤ 五反田本店                 東京都品川区西五反田１－４－２        54
# 2  幻の和牛と三崎港直送鮮魚 MORGEN 五反田駅前店      東京都品川区西五反田１-18-1 五反田EXビル7F        70
# 3               酒蔵 桜ちょうちん 五反田  東京都品川区西五反田１‐4‐2 秀和五反田駅前レジデンス2階       150
# 4              居酒屋 せんや 五反田駅本店      東京都品川区東五反田１-17-7大宗五反田ビル202       100
#
#                                    access  \
# 0                         ＪＲ五反田駅西口より徒歩約2分
# 1    ＪＲ五反田駅西口から 徒歩1分 (旧野村証券ビル裏)/五反田駅から87m
# 2            五反田駅徒歩3分／大崎広小路駅徒歩1分／大崎駅徒歩10分
# 3  JR五反田駅徒歩２分/都営浅草線五反田駅徒歩２分/東急池上線五反田駅徒歩２分
# 4     各線五反田駅東口徒歩２分／鹿児島黒牛や鮮度抜群の刺身を完全個室で堪能♪
#
#                                                 open      budget  \
# 0  月～日、祝日、祝前日: 11:00～14:30 （料理L.O. 14:00 ドリンクL.O....  3001～4000円
# 1  月: 11:30～14:30 （料理L.O. 14:00 ドリンクL.O. 14:00）17...  4001～5000円
# 2  月、日、祝日: 17:00～22:30 （料理L.O. 22:00 ドリンクL.O. 22:...  3001～4000円
# 3  月～金: 16:00～23:30 （料理L.O. 22:30 ドリンクL.O. 23:00）...  3001～4000円
# 4  月～金、日、祝前日: 16:00～翌0:00 （料理L.O. 23:00 ドリンクL.O. ...  3001～4000円
#
#                                                 urls
# 0  https://www.hotpepper.jp/strJ004402152/?vos=nh...
# 1  https://www.hotpepper.jp/strJ000132490/?vos=nh...
# 2  https://www.hotpepper.jp/strJ001278727/?vos=nh...
# 3  https://www.hotpepper.jp/strJ003893833/?vos=nh...
# 4  https://www.hotpepper.jp/strJ001244947/?vos=nh...

# %%
_budget = df['budget'][0]
_budget
_budget.split('～')
int(_budget.split('～')[0])
_budget.split('～')[1].replace('円','')
int(_budget.split('～')[1].replace('円',''))
# Out:
# 4000

# %%
lower_budgets = []
upper_budgets = []

for _budget in df['budget']:
    if _budget != '':
        lower_budget = int(_budget.split('～')[0])
        upper_budget = int(_budget.split('～')[1].replace('円',''))
    else:
        lower_budget = 0
        upper_budget = 0

    lower_budgets.append(lower_budget)
    upper_budgets.append(upper_budget)

# %%
df['lower_budget'] = lower_budgets
df['upper_budget'] = upper_budgets
df.head()
# Out:
#                          name                         address  capacity  \
# 0                   海坊主五反田駅前店          東京都品川区西五反田２-７-８ 誠實ビル7階        95
# 1          王豚足家 オウトンソクヤ 五反田本店                 東京都品川区西五反田１－４－２        54
# 2  幻の和牛と三崎港直送鮮魚 MORGEN 五反田駅前店      東京都品川区西五反田１-18-1 五反田EXビル7F        70
# 3               酒蔵 桜ちょうちん 五反田  東京都品川区西五反田１‐4‐2 秀和五反田駅前レジデンス2階       150
# 4              居酒屋 せんや 五反田駅本店      東京都品川区東五反田１-17-7大宗五反田ビル202       100
#
#                                    access  \
# 0                         ＪＲ五反田駅西口より徒歩約2分
# 1    ＪＲ五反田駅西口から 徒歩1分 (旧野村証券ビル裏)/五反田駅から87m
# 2            五反田駅徒歩3分／大崎広小路駅徒歩1分／大崎駅徒歩10分
# 3  JR五反田駅徒歩２分/都営浅草線五反田駅徒歩２分/東急池上線五反田駅徒歩２分
# 4     各線五反田駅東口徒歩２分／鹿児島黒牛や鮮度抜群の刺身を完全個室で堪能♪
#
#                                                 open      budget  \
# 0  月～日、祝日、祝前日: 11:00～14:30 （料理L.O. 14:00 ドリンクL.O....  3001～4000円
# 1  月: 11:30～14:30 （料理L.O. 14:00 ドリンクL.O. 14:00）17...  4001～5000円
# 2  月、日、祝日: 17:00～22:30 （料理L.O. 22:00 ドリンクL.O. 22:...  3001～4000円
# 3  月～金: 16:00～23:30 （料理L.O. 22:30 ドリンクL.O. 23:00）...  3001～4000円
# 4  月～金、日、祝前日: 16:00～翌0:00 （料理L.O. 23:00 ドリンクL.O. ...  3001～4000円
#
#                                                 urls  lower_budget  \
# 0  https://www.hotpepper.jp/strJ004402152/?vos=nh...          3001
# 1  https://www.hotpepper.jp/strJ000132490/?vos=nh...          4001
# 2  https://www.hotpepper.jp/strJ001278727/?vos=nh...          3001
# 3  https://www.hotpepper.jp/strJ003893833/?vos=nh...          3001
# 4  https://www.hotpepper.jp/strJ001244947/?vos=nh...          3001
#
#    upper_budget
# 0          4000
# 1          5000
# 2          4000
# 3          4000
# 4          4000

# %%
df['upper_budget'] <= 4000
df_filtered = df[df['upper_budget'] <= 4000]
df_filtered.head()
# Out:
#                             name                           address  capacity  \
# 0                      海坊主五反田駅前店            東京都品川区西五反田２-７-８ 誠實ビル7階        95
# 2     幻の和牛と三崎港直送鮮魚 MORGEN 五反田駅前店        東京都品川区西五反田１-18-1 五反田EXビル7F        70
# 3                  酒蔵 桜ちょうちん 五反田    東京都品川区西五反田１‐4‐2 秀和五反田駅前レジデンス2階       150
# 4                 居酒屋 せんや 五反田駅本店        東京都品川区東五反田１-17-7大宗五反田ビル202       100
# 5  0秒レモンサワー 仙台ホルモン焼肉酒場 ときわ亭 五反田店  東京都品川区西五反田１丁目４－８　秀和五反田駅前レジデンス　２Ｆ        63
#
#                                    access  \
# 0                         ＪＲ五反田駅西口より徒歩約2分
# 2            五反田駅徒歩3分／大崎広小路駅徒歩1分／大崎駅徒歩10分
# 3  JR五反田駅徒歩２分/都営浅草線五反田駅徒歩２分/東急池上線五反田駅徒歩２分
# 4     各線五反田駅東口徒歩２分／鹿児島黒牛や鮮度抜群の刺身を完全個室で堪能♪
# 5   JR 五反田駅　 徒歩2分　都営浅草線五反田駅徒歩2分★ときわ亭五反田店★
#
#                                                 open      budget  \
# 0  月～日、祝日、祝前日: 11:00～14:30 （料理L.O. 14:00 ドリンクL.O....  3001～4000円
# 2  月、日、祝日: 17:00～22:30 （料理L.O. 22:00 ドリンクL.O. 22:...  3001～4000円
# 3  月～金: 16:00～23:30 （料理L.O. 22:30 ドリンクL.O. 23:00）...  3001～4000円
# 4  月～金、日、祝前日: 16:00～翌0:00 （料理L.O. 23:00 ドリンクL.O. ...  3001～4000円
# 5  月～木: 17:00～23:30 （料理L.O. 22:30 ドリンクL.O. 22:30）...  2001～3000円
#
#                                                 urls  lower_budget  \
# 0  https://www.hotpepper.jp/strJ004402152/?vos=nh...          3001
# 2  https://www.hotpepper.jp/strJ001278727/?vos=nh...          3001
# 3  https://www.hotpepper.jp/strJ003893833/?vos=nh...          3001
# 4  https://www.hotpepper.jp/strJ001244947/?vos=nh...          3001
# 5  https://www.hotpepper.jp/strJ001266670/?vos=nh...          2001
#
#    upper_budget
# 0          4000
# 2          4000
# 3          4000
# 4          4000
# 5          3000
